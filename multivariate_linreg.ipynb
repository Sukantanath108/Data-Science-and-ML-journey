# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukantanath108/Data-Science-and-ML-journey/blob/main/multivariate_linreg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install word2number
 import numpy as np
 import pandas as pd
 import matplotlib.pyplot as plt
 import seaborn as sns
 from word2number import w2n
 import warnings
 warnings.filterwarnings('ignore')
 # %matplotlib
# Out:
# ...
# Using matplotlib backend: agg

# %%
df = pd.read_csv('hiring.csv')
df.shape
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.isnull().sum()
# Out:
# experience                    2
# test_score(out of 10)         1
# interview_score(out of 10)    0
# salary($)                     0
# dtype: int64

# %%
df['experience'] = df['experience'].fillna('zero')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df['experience'] = df['experience'].apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
import math
median_test_score = math.floor(df['test_score(out of 10)'].mean())
median_test_score
# Out:
# 7

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(median_test_score)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:, -1].values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
r2_score(y, lr.predict(X))
# Out:
# 0.9770139014273139

# %%
lr.predict(np.array([[7,10,10]]))
# Out:
# array([[79136.4512114]])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y, lr.predict(X))
print(f"the mse is : {mse}")
# Out:
# the mse is : 2660640.9097884106
